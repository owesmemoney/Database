# %% [markdown]
# <div style="font-size:48px; line-height:1.2;">
#     <center>
# COMS W4111-002/V02, Spring 22: <br>Take Home Midterm
# </center>
#
#
# <hr style="height:2px;">
# <br>

# %% [markdown]
# # Overview

# %% [markdown]
# <div style="color:red;font-size:24px; line-height:1.3 ">
#     <u>NOTE:</u>
# <ul>
#     <li>This is a draft of the midterm exam. We are releasing the draft to enable students to start thinking about the exam and potentially identifying material that needs clarification.
#     <li>Despite being a draft, the only changes will be clarifications. So, students can begin thinking about and working on answers.
#     <li>The TAs will provide guidance for submission formats and annotations.
#     </ul>
# </div>

# %% [markdown]
# ## Instructions

# %% [markdown]
# - __TA TODO:__ TAs to finalize instructions, especially submission instructions.

# %% [markdown]
# ### Due Date, Completing the Exam and Rules
#
# 1. The midterm exam is due at 11:59 PM on Monday, 28-MAR-2022. __You are not allowed to use late days.__
# <br><br>
# 2. You may use on-line information and sources to answer questions. But,
#     1. You cannot simply cut and paste answers or code. You answer must demonstrate that you understood the material and are capable of producing an answer from your understanding.
#     2. You must cite any only sources of information that you used. This can simply be a comment in a text/markdown cell in your answer. For example,  ```(Note: I used https://www.w3schools.com/sql/sql_check.asp to help me with the syntax for adding a check constraint).```
#     3. You do NOT need to cite lecture notes, recordings, slides, ... You do not need to cite information from the recommended textbook or textbook slides.
# <br><br>
# 3. You MUST NOT collaborate with ANYONE, including other students. You MAY speak with the professor or a TA to discuss the exam.
# <br><br>
# 4. If you have questions, post them as PRIVATE question on Ed dicussion and use the Category ```Exams->Midterm.```
# <br><br>
# 5. There is a pinned Ed discussion topic [Midterm Clarifications](https://edstem.org/us/courses/18760/discussion/1302989) that the professor and TA will use to communicate updates and clarifications. __Students are responsible for checking this post.__

# %% [markdown]
# ### Submission Format and Instructions
#
# - __TA TODO:__ TAs to finalize instructions, especially submission instructions.

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# __Notes:__<br>
#
# 1. This section tests your environment.
# <br><br>
# 1. You will need to change the MySQL userID and password in some of the cells below to match your configuration.<br><br>
# 2. You may need to load data and copy databases. The relevant questions provide information.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:Zxw981120+@localhost
# Out:
# 'Connected: root@None'

# %%
from sqlalchemy import create_engine

# %%
sql_engine = create_engine("mysql+pymysql://root:Zxw981120+@localhost")

# %%
import pandas as pd

# %%
sql = """
    select customerName, customerNumber, city, country from classicmodels.customers
        where country = 'France'
"""

res = pd.read_sql(sql, con=sql_engine)

# %%
res
# Out:
#                  customerName  customerNumber        city country
# 0           Atelier graphique             103      Nantes  France
# 1           La Rochelle Gifts             119      Nantes  France
# 2      Saveley & Henriot, Co.             146        Lyon  France
# 3    Daedalus Designs Imports             171       Lille  France
# 4   La Corne D'abondance, Co.             172       Paris  France
# 5                 Mini Caravy             209  Strasbourg  France
# 6                Alpha Cognac             242    Toulouse  France
# 7             Lyon Souveniers             250       Paris  France
# 8        Auto Associés & Cie.             256  Versailles  France
# 9        Marseille Mini Autos             350   Marseille  France
# 10         Reims Collectables             353       Reims  France
# 11          Auto Canal+ Petit             406       Paris  France

# %%
import pymysql

# %%
sql_conn = pymysql.connect(
    user="root",
    password='Zxw981120+',
    host="localhost",
    port=3306,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True)

# %%
cur = sql_conn.cursor()

res = cur.execute(sql)
res = cur.fetchall()
res
# Out:
# [{'customerName': 'Atelier graphique',
#   'customerNumber': 103,
#   'city': 'Nantes',
#   'country': 'France'},
#  {'customerName': 'La Rochelle Gifts',
#   'customerNumber': 119,
#   'city': 'Nantes',
#   'country': 'France'},
#  {'customerName': 'Saveley & Henriot, Co.',
#   'customerNumber': 146,
#   'city': 'Lyon',
#   'country': 'France'},
#  {'customerName': 'Daedalus Designs Imports',
#   'customerNumber': 171,
#   'city': 'Lille',
#   'country': 'France'},
#  {'customerName': "La Corne D'abondance, Co.",
#   'customerNumber': 172,
#   'city': 'Paris',
#   'country': 'France'},
#  {'customerName': 'Mini Caravy',
#   'customerNumber': 209,
#   'city': 'Strasbourg',
#   'country': 'France'},
#  {'customerName': 'Alpha Cognac',
#   'customerNumber': 242,
#   'city': 'Toulouse',
#   'country': 'France'},
#  {'customerName': 'Lyon Souveniers',
#   'customerNumber': 250,
#   'city': 'Paris',
#   'country': 'France'},
#  {'customerName': 'Auto Associés & Cie.',
#   'customerNumber': 256,
#   'city': 'Versailles',
#   'country': 'France'},
#  {'customerName': 'Marseille Mini Autos',
#   'customerNumber': 350,
#   'city': 'Marseille',
#   'country': 'France'},
#  {'customerName': 'Reims Collectables',
#   'customerNumber': 353,
#   'city': 'Reims',
#   'country': 'France'},
#  {'customerName': 'Auto Canal+ Petit',
#   'customerNumber': 406,
#   'city': 'Paris',
#   'country': 'France'}]

# %%
cur.close()

# %% [markdown]
# # Written Questions

# %% [markdown]
# __Note:__
#
# "If you can’t explain something in a few words, try fewer."
# – Robert Brault
#
# "Professor Ferguson has the patience of a ferret that just drank a double espresso. If your answer is long, he gets bored and cranky, and deducts points." - Anonymous TA advising students in a previous semester.
#
# - We expect brief, succinct answers.<br><br>
# - We deduct points for bloviating.<br><br>

# %% [markdown]
# ## W1

# %% [markdown]
# Briefly explain the differences between:
# 1. _Candidate Key_ and _Super Key._
# 2. _Primary Key_ and _Unique_Key._
# 3. _Natural Key_ and _Surrogate Key._

# %% [markdown]
# <u>Answer</u>
# 1. Candidate keys are the subset of Super Key. All the candidate keys are the super keys but not all the super keys are candidate keys.
# 2. Each table could contain only one Primary key but could have several Unique keys.
# 3. A natural Key is a column that already exists in the table while the surrogate key is a system generated value.

# %% [markdown]
# ## W2

# %% [markdown]
# 1. Define the concept of _immutable_ columns (data).
# 2. What is a benefit of using immutable columns to define a primary key.

# %% [markdown]
# <u>Answer</u>
# ```
# Immutable columns(data) refers to the data that should not be deleted or changed.
# Defining a primary key using immutable columns helps in thread safe. No matter when we call the primary key, it guarantees that we have the unique and original data.
# ```

# %% [markdown]
# ## W3

# %% [markdown]
# Codd's Third Rule states, "Null values (distinct from the empty character string or a string of blank characters and distinct from zero or any other number) are supported in fully relational DBMS for representing missing information and inapplicable information in a systematic way, independent of data type."
#
# Briefly explain the value of this rule, and provide two examples.

# %% [markdown]
# <u>Answer</u>
# ```
# Having Null values in fully relational DBMS is reliable as it will not confuse programmers about datatype in sql statement. It could used when data value is unknown or unavailable or not applicable.
# For example, dorm number attribute of address may only apply to the address in dorm, so when not appliable, the value could be NULL.
# Or if we count how many class a student takes, the value could be NULL when the data is unavailable.
# ```

# %% [markdown]
# ## W4
#
# The relational model and SQL are _closed_ under their operations. Briefly explain what this concept means.

# %% [markdown]
# <u>Answer</u>
# ```
# Be closed under operations for relational model and SQL means that the tables included are connected as the output from one operation could be used as input in another operation.
# ```

# %% [markdown]
# ## W5

# %% [markdown]
# Codd's 6th rule states, "All views that are theoretically updatable are also updatable by the system."
#
# Using the following table definition, use SQL (```CREATE VIEW```) to define:
# 1. Two views of the table that are theoretically not possible to update.
# 2. One view that is theoretically possible to update.
#
# - You do not need to execute the create statement. We are focusing on your understanding.
#
#
# ```
# create table S22_W4111_Midterm.midterm_students
# (
# 	social_security_no char(9) not null
# 		primary key,
# 	last_name varchar(64) null,
# 	first_name varchar(64) null,
# 	enrollment_year year null,
# 	total_credits int null
# );
# ```

# %% [markdown]
# <u>Answer</u>
# ```
# Two views that not possible to update:
# CREATE VIEW social_no AS SELECT social_security_no FROM S22_W4111_Midterm.midterm_students;
#
# CREATE VIEW enrollment AS SELECT enrollment_year FROM
# S22_W4111_Midterm.midterm_students;
#
# One view that possible to update:
# CREATE VIEW name AS SELECT first_name FROM
# S22_W4111_Midterm.midterm_students;
# ```

# %% [markdown]
# ## W6
#
# In the Columbia University [directory of classes,](http://www.columbia.edu/cu/bulletin/uwb/#/cu/bulletin/uwb/subj/COMS/W4111-20213-002) the "Section Key" for this course is ```20213COMS4111W002```.
#
# - Explain why having a column ```section_key varchar(17)``` that holds section key values is not-atomic.
# - Give two explanations for why using the section key (not atomic data) for a column causes problems.

# %% [markdown]
# <u>Answer</u>
# ```
# Becasue this section key value could be further divided into time of section, department of section and way of teaching like 'W'.
# Two explanations: Using not-atomic data might casue more logical action when updating several records in one database.Also, it might cause problems when two different process access the same variable.
# ```

# %% [markdown]
# ## W7

# %% [markdown]
# Briefly explain the differences between:
#
# - Database stored procedure
# - Database function
# - Database trigger

# %% [markdown]
# <u>Answer</u>
# 1. Both Database trigger and stored procedure could update data but database function could not.
# 2. Only Database function could be part of a query but the other two could not.
# 3. Both Database function and stored procedure could be called explicitly but trigger could not.

# %% [markdown]
# ## W8

# %% [markdown]
# Briefly explain:
#
# - Natural join
# - Equi-join
# - Theta join
# - Self-join

# %% [markdown]
# <u>Answer</u>
# 1. Natural Join matches the same values of all common attributes and returns one copy of common column.
# 2. Equi-join is a type of join that combines tables based on same values for specified columns.
# 3. Theta join is a type of join that allows arbitary operations except equality.
# 4. Self-join is a type of join that the table join with itself.

# %% [markdown]
# ## W9

# %% [markdown]
# Consider the schema for [Classic Models,](https://www.mysqltutorial.org/mysql-sample-database.aspx) which we have used in the class.
#
# 1. Is any entity type in the schema a _weak entity?_ If yes, list one of the weak entity types.
# 2. In database design, using ```ON DELETE CASCADE``` may not be a desired behavior/design. Why is it more likely that ```ON DELETE CASCADE``` is the correct behavior for weak entities when the referencing row is deleted?

# %% [markdown]
# <u>Answer</u>
# ```
# Weak entity types in Classic Models: payments
# Because Weak entity types reply on another entity by uniquely identified from other PK, therefore when rows in parent
# table is deleted, the row in weak entity might not be useful. For example, if the customers account is deleted, we also want to delete the payments  as well.
# ```

# %% [markdown]
# ## W10

# %% [markdown]
# 1. Briefly explain the concept of a _database cursor._
# 2. Why is using a cursor sometimes helpful for applications processing database information.

# %% [markdown]
# <u>Answer</u>
# ```
# Database cursor is like a pointer to the current row with the ability to add or remove database records.
# Database cursor saves both time and memory for processing information of recordset.
#
# reference:https://www.ibm.com/docs/en/informix-servers/12.10?topic=sql-database-cursor
# ```

# %% [markdown]
# # Relational Algebra

# %% [markdown]
# ## R1

# %% [markdown]
# - You can assume that the type for the columns in this question are ```TEXT.```
# - Translate the following relational schema definition into an equivalent SQL ```CREATE TABLE``` statement.
# - You do not need to execute the statement. We are focusing on understanding.
#
# \begin{equation}
# (\underline{branch\_id}, \underline{account\_id}, balance)
# \end{equation}

# %% [markdown]
# <u>Answer</u>
# ```
# CREATE TABLE R1 (
#     balance TEXT NOT NULL,
#     CONSTRAINT PK_R1 PRIMARY KEY (branch_id,account_id)
# );
# ```

# %% [markdown]
# ## R2

# %% [markdown]
# - Use the RelaX online calculator with the [Silberschatz - UniversityDB](https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0) for this query.
# - You may use __only__ the ```ρ (pi), σ, ⟕, ⟖, ⨝``` for this question. You can use predicates/conditions for the query, and column list for the project.
# - Write a relational algebra statement that produces a table containing the ```ID``` and ```name``` of instructors who do not advise any students. Your result should be of the form:
#
# ```(ID, name)```
#
# - Your answer must contain the query statement (in text, not in an image) and a screen capture of the query execution and result. An example of the structure of the answer is:
#
# Query:
#
# ```σ building='Watson' (classroom)```
#
# Screen capture:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <u>Answer</u>
#
# Query:
# ```
# π ID, name ((π ID, name (instructor))-((π ID, name (σ ID = advisor.i_id (instructor ⟖ advisor )))))
# ```
#
#
# Screen Capture:

# %%
er_model_file_name = 'R2.png'
print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# ## R3

# %% [markdown]
# - Use the RelaX online calculator with the [Silberschatz - UniversityDB](https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0) for this query.
# - You may only use the relational operators ```π, σ, ⨝``` for the solution. You may use column lists and conditions/predicates.
# - Write a relational algebra expression equivalent to the following SQL statement.
#
# ```
# select * from takes
# 	where course_id in
# 	      (select course_id from course where dept_name not in
#               (select dept_name from department where building='Taylor'))
# 	and
#     year='2009';
# ```
#
# - __Note:__
#     - The book's sample data you loaded into MySQL is different from the data in the RelaX calculator. RelaX has data from a prior version of the book.
#     - If you want to test the SQL statement in MySQL, you can load the [data from version 6](https://www.db-book.com/db6/lab-dir/sample_tables-dir/index.html) of the book into a separate schema in MySQL.

# %% [markdown]
# <u>Answer</u>
#
# Query:
# ```
# π ID, course_id, sec_id,semester,year,grade (π ID,course_id,sec_id,semester,year,grade,building (σbuilding≠'Taylor'∧ year =2009 (department⨝course⨝takes)))
# ```
#
# Screen Capture:

# %%
er_model_file_name = 'R3.png'
print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# # Entity Relationship Model

# %% [markdown]
# - Setup:
#     - Being able to translate a written description of a schema into an ER diagram is an important skill.
#     - This question tests that skill by describing a data model that you have to define using Crow's Foot Notation.
#     - You ER model must be implementable in SQL DDL.
#     - You do not need to choose data types for columns.
#     - You should add notes to your diagram for clarification if you think necessary.

# %% [markdown]
# ## ER1

# %% [markdown]
# - Description:
#     - There are two entity types:
#         1. \begin{equation}Person(\underline{person\_id}, last\_name, first\_name)\end{equation}
#         2. \begin{equation}Address(\underline{address\_id}, address\_line, city, state, zip\_code)\end{equation}
#     - There are two many-to-many relationships:
#         1. $Person-Address:$ A $Person$ $lives\_at$ an $Address$ from a $start\_date$ to an $end\_date$.
#         2. $Person-Person:$ A $Person$ $became\_friends\_with$ a $Person$ on a $friend\_date$
#     - You do not need to worry about semantics constraints, e.g. it is OK if $lives\_at$ terms overlap.
#
#
# - __Notes:__
#     - Use LucidChart to draw your ER diagram.
#     - You do not need to worry about data types.
#     - You must show primary and foreign keys.
#     - You do not need to worry about semantics constraints, e.g. it is OK if $lives\_at$ terms overlap.
#     - Put your diagram in the directory that contains your notebook and include following instructions provided for previous homework assignments.

# %%
er_model_file_name = 'ER1.png'
print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# ## ER2
#
# - Description:
#     - There are three entity types:
#         1. \begin{equation}CheckingAccount(\underline{checking\_id}, balance)\end{equation}
#         2. \begin{equation}SavingsAccount(\underline{savings\_id}, balance)\end{equation}
#         3. \begin{equation}Person(\underline{person\_id}, last\_name, first\_name)\end{equation}
#     - A $Portfolio$ is an entity type that:
#         1. Has a primary key $portfolio\_id$.
#         2. _Aggregates_ other entity types:
#             - Exactly one $primary\_customer$.
#             - At most one $secondary\_customer$.
#             - Exactly one $checking\_account$.
#             - Exactly one $savings\_account$.
#
#
# - __Notes:__
#     - Use LucidChart to draw your ER diagram.
#     - You do not need to worry about data types.
#     - You must show primary and foreign keys.
#     - You do not need to worry about semantics constraints, e.g. it is OK of the same person is the primary and secondary customer.

# %%
er_model_file_name = 'ER2.png'
print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# # SQL Schema and DDL

# %% [markdown]
# ## DDL1

# %% [markdown]
# - You have a logical datamodel ER-diagram (see below).
#
#
# - You need to use DDL to define a schema that realizes the model.
#
#
# - Logical models are not specific enough for direct implementation. This means that:
#     - You will have to assign concrete types to columns, and choose things like ```GENERATED,``` ```DEFAULT,``` etc.
#     - You have to make assumptions about things like ```NOT NULL.```
#     - You may have to decompose a table into two tables, or extract common attributes from multiple tables into a single, referenced table.
#     - Implementing the relationships may require adding columns and foreign keys, associative entities, etc.
#     - You may have to make other design and implementation choices. <b>This means that there is no single correct answer.</b>
#
#
# - In addition to the key constraints, you must also implement the following constraints:
#     - ```email``` values must contain a ```@``` and end in ```.edu```
#     - ```semester``` must be ```fall, spring``` or ```summer```
#     - ```year``` must be greater than or equal to 2021 and less than or equal to 2023.

# %% [markdown]
# | <img src="./school_er_diagram.png"> |
# | :---: |
# | __ER Diagram__ |

# %% [markdown]
# <u>Answer</u>

# %% [markdown]
# _Design Decisions, Notes, etc._ Document any assumption or decisions.

# %% [markdown]
# _DDL_
#
# - Execute your DDL in the cell below. You may use DataGrip or other tools to help build the schema and statements.
#
#
# - You can copy and paste the ```SQL CREAT TABLE``` below, but you MUST execute the statements.

# %%
# DDL in cells below.
# Use you UNI for the schema.

# %sql create schema if not exists dff9_s22_midterm;
# %sql select 1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(1,)]

# %%
# SQL tests. 
# Test your DDL with sample inserts/updates showing that you correctly implemented constraints.
#

# %%
# %%sql
# create table StudentSection
# (
#     role  varchar(255),
#     UNI   int(255)  not null,
#     call_no int(255)  not null,
#     constraint StudentSection_pk primary key (UNI)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table Student
# (
#     UNI int(255) not null,
#     last_name  varchar(255),
#     first_name varchar(255),
#     email      varchar(255),
#     constraint Student_pk primary key (UNI)
# );
#
# create unique index Student_email_uindex on Student (email);
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# create table School(
#     school_code int(255) not null,
#     school_name varchar(255),
#     constraint school_pk primary key (school_code)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table Course
# (
#     course_no   int(255),
#     title       varchar(255),
#     description text,
#     constraint Course_pk primary key (course_no)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table Department
# (
#     department_code int(255) not null,
#     department_name varchar(255),
#     constraint Department_pk primary key (department_code)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table Faculty
# (
#     UNI        int(255) not null,
#     last_name  varchar(255),
#     first_name varchar(255),
#     email      varchar(255),
#     department_code int(255) not null,
#     constraint Faculty_pk primary key(UNI),
#     foreign key(department_code) references Department(department_code),
#     UNIQUE(email)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table SchoolDepartment
# (
#     school_code int(255) not null,
#     department_code int(255),
#     constraint SchoolDepartment_pk primary key (school_code),
#     foreign key(department_code) references Department(department_code)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table Section
# (
#     call_no int(255) not null,
#     course_no int(255),
#     section_no varchar(255),
#     semester varchar(255),
#     year int(255),
#     instructor_id int(255),
#     email varchar(255),
#     constraint Section_pk primary key (call_no),
#     foreign key(instructor_id) references Faculty(UNI),
#     UNIQUE(year),
#     UNIQUE(semester),
#     UNIQUE(section_no),
#     CHECK (year>=2021 and year <=2023)
#
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE Section
# ADD CONSTRAINT CHK_Section CHECK (semester ='spring' or semester ='fall'or semester='summer');
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE Section
# ADD CONSTRAINT CHK_email CHECK (email like '%_@__%.edu');
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# # SQL Queries

# %% [markdown]
# - You will use the [Classic Models](https://www.mysqltutorial.org/mysql-sample-database.aspx) data for these questions.
#
#
# - You loaded this database in a previous HW and tested that you have the database in the setup section.

# %% [markdown]
# ## S1
#
# - Produce a table of the form: $(productLine, productName, productVendor, total\_revenue)$
#
#
# - The contribution to total_value for an $orderLine$ is $quantityOrdered*priceEach$
#
#
# - Total value is the sum of the $orderLine$ contributions for all $productCodes$ in a $productLine.$
#
#
# - Only include results with $total\_value$ greater or equal to ```$150000``` and sorted by $total\_value$ descending.
#
#
# - __NOTE:__ You should be able to produce the answer without my providing the correct query output. I was giggling diabolically like the Riddler from Batman when writing the question. Then something like the following happened.
# <br><br>
#
# ![image.png](attachment:image.png)
#
#
# - So the output is below.

# %%
# %sql select * from classicmodels.midterm_s1;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 6 rows affected.
# [('Classic Cars', '1992 Ferrari 360 Spider red', 'Unimax Art Galleries', Decimal('276839.98')),
#  ('Classic Cars', '2001 Ferrari Enzo', 'Second Gear Diecast', Decimal('190755.86')),
#  ('Classic Cars', '1952 Alpine Renault 1300', 'Classic Metal Creations', Decimal('190017.96')),
#  ('Motorcycles', '2003 Harley-Davidson Eagle Drag Bike', 'Red Start Diecast', Decimal('170686.00')),
#  ('Classic Cars', '1968 Ford Mustang', 'Autoart Studio Design', Decimal('161531.48')),
#  ('Classic Cars', '1969 Ford Falcon', 'Second Gear Diecast', Decimal('152543.02'))]

# %% [markdown]
# - Put your query below. You do not need to create a view.

# %%
# %%sql
# use classicmodels;
#
# with product_basic as
# (select productCode, productLine, productName, productVendor from products),
# total_com as
# (select productCode, sum(quantityOrdered*priceEach) as total_revenue from orderdetails group by productCode)
#
# select productLine, productName, productVendor, total_revenue from product_basic join total_com using(productCode) where total_revenue>=150000 order by total_revenue DESC;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 6 rows affected.
# [('Classic Cars', '1992 Ferrari 360 Spider red', 'Unimax Art Galleries', Decimal('276839.98')),
#  ('Classic Cars', '2001 Ferrari Enzo', 'Second Gear Diecast', Decimal('190755.86')),
#  ('Classic Cars', '1952 Alpine Renault 1300', 'Classic Metal Creations', Decimal('190017.96')),
#  ('Motorcycles', '2003 Harley-Davidson Eagle Drag Bike', 'Red Start Diecast', Decimal('170686.00')),
#  ('Classic Cars', '1968 Ford Mustang', 'Autoart Studio Design', Decimal('161531.48')),
#  ('Classic Cars', '1969 Ford Falcon', 'Second Gear Diecast', Decimal('152543.02'))]

# %% [markdown]
# ## S2

# %% [markdown]
# - Produce a table containing the rows from ```products``` for any products not in any ```orderDetails.```

# %%
# %%sql select* from products where productCode not in (
# select productCode from orderDetails)
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('S18_3233', '1985 Toyota Supra', 'Classic Cars', '1:18', 'Highway 66 Mini Classics', 'This model features soft rubber tires, working steering, rubber mud guards, authentic Ford logos, detailed undercarriage, opening doors and hood, removable split rear gate, full size spare mounted in bed, detailed interior with opening glove box', 7733, Decimal('57.01'), Decimal('107.57'))]

# %% [markdown]
# ## S3

# %% [markdown]
# - Define ```order_time``` to be the number of days between ```orders.orderDate``` and ```orders.shippedDate.```
#
#
# - The following tables has the form ```(customerNumber, customerName, orderNumber, order_time)``` for
#     - Customers with ```customers.country``` in USA or Canada.
#     - And the ```orders.status``` is not ```Cancelled.```
#
#
# - Your answer must match the sample below, including row order.

# %%
# %sql select * from classicmodels.midterm_s3;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 46 rows affected.
# [(328, 'Tekni Collectables Inc.', 10401, None),
#  (450, 'The Sharp Gifts Warehouse', 10407, None),
#  (362, 'Gifts4AllAges.com', 10414, None),
#  (124, 'Mini Gifts Distributors Ltd.', 10421, None),
#  (157, 'Diecast Classics Inc.', 10422, None),
#  (161, 'Technics Stores Inc.', 10140, 6),
#  (205, 'Toys4GrownUps.com', 10145, 6),
#  (219, 'Boards & Toys Co.', 10154, 6),
#  (321, 'Corporate Gift Ideas Co.', 10159, 6),
#  (347, "Men 'R' US Retailers, Ltd.", 10160, 6),
#  (462, 'FunGiftIdeas.com', 10166, 6),
#  (175, 'Gift Depot Inc.', 10172, 6),
#  (124, 'Mini Gifts Distributors Ltd.', 10182, 6),
#  (320, 'Mini Creations Ltd.', 10185, 6),
#  (205, 'Toys4GrownUps.com', 10189, 6),
#  (328, 'Tekni Collectables Inc.', 10251, 6),
#  (204, 'Online Mini Collectables', 10276, 6),
#  (198, 'Auto-Moto Classics Inc.', 10290, 6),
#  (339, 'Classic Gift Ideas, Inc', 10307, 6),
#  (161, 'Technics Stores Inc.', 10317, 6),
#  (363, 'Online Diecast Creations Co.', 10322, 6),
#  (486, 'Motor Mint Distributors Inc.', 10331, 6),
#  (198, 'Auto-Moto Classics Inc.', 10352, 6),
#  (462, 'FunGiftIdeas.com', 10388, 6),
#  (129, 'Mini Wheels Co.', 10111, 5),
#  (198, 'Auto-Moto Classics Inc.', 10130, 5),
#  (447, 'Gift Ideas Corp.', 10131, 5),
#  (124, 'Mini Gifts Distributors Ltd.', 10142, 5),
#  (487, 'Signal Collectibles Ltd.', 10149, 5),
#  (363, 'Online Diecast Creations Co.', 10192, 5),
#  (455, 'Super Scale Inc.', 10196, 5),
#  (475, 'West Coast Collectables Co.', 10199, 5),
#  (239, 'Collectable Mini Designs Co.', 10226, 5),
#  (486, 'Motor Mint Distributors Inc.', 10236, 5),
#  (181, 'Vitachrome Inc.', 10237, 5),
#  (456, 'Microscale Inc.', 10242, 5),
#  (455, 'Super Scale Inc.', 10245, 5),
#  (233, 'Québec Home Shopping Network', 10261, 5),
#  (319, 'Mini Classics', 10308, 5),
#  (157, 'Diecast Classics Inc.', 10318, 5),
#  (424, 'Classic Legends Inc.', 10337, 5),
#  (161, 'Technics Stores Inc.', 10362, 5),
#  (124, 'Mini Gifts Distributors Ltd.', 10368, 5),
#  (219, 'Boards & Toys Co.', 10376, 5),
#  (124, 'Mini Gifts Distributors Ltd.', 10396, 5),
#  (233, 'Québec Home Shopping Network', 10411, 5)]

# %% [markdown]
# - Put your query below. You do not need to create a view.

# %%
# %%sql
#
# use classicmodels;
#
# with order_form as (
#     select customerNumber,orderNumber, status, DATEDIFF(shippedDate, orderDate) as order_time from orders where status<>'Cancelled'),
# customer_form as (
#     select customerNumber, customerName from customers WHERE country = 'USA' or country = 'Canada'
# )
# select customerNumber, customerName, orderNumber, order_time from customer_form join order_form using (customerNumber) order by order_time is null desc, order_time DESC;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 118 rows affected.
# [(124, 'Mini Gifts Distributors Ltd.', 10421, None),
#  (157, 'Diecast Classics Inc.', 10422, None),
#  (328, 'Tekni Collectables Inc.', 10401, None),
#  (362, 'Gifts4AllAges.com', 10414, None),
#  (450, 'The Sharp Gifts Warehouse', 10407, None),
#  (124, 'Mini Gifts Distributors Ltd.', 10182, 6),
#  (161, 'Technics Stores Inc.', 10140, 6),
#  (161, 'Technics Stores Inc.', 10317, 6),
#  (175, 'Gift Depot Inc.', 10172, 6),
#  (198, 'Auto-Moto Classics Inc.', 10290, 6),
#  (198, 'Auto-Moto Classics Inc.', 10352, 6),
#  (204, 'Online Mini Collectables', 10276, 6),
#  (205, 'Toys4GrownUps.com', 10145, 6),
#  (205, 'Toys4GrownUps.com', 10189, 6),
#  (219, 'Boards & Toys Co.', 10154, 6),
#  (320, 'Mini Creations Ltd.', 10185, 6),
#  (321, 'Corporate Gift Ideas Co.', 10159, 6),
#  (328, 'Tekni Collectables Inc.', 10251, 6),
#  (339, 'Classic Gift Ideas, Inc', 10307, 6),
#  (347, "Men 'R' US Retailers, Ltd.", 10160, 6),
#  (363, 'Online Diecast Creations Co.', 10322, 6),
#  (462, 'FunGiftIdeas.com', 10166, 6),
#  (462, 'FunGiftIdeas.com', 10388, 6),
#  (486, 'Motor Mint Distributors Inc.', 10331, 6),
#  (124, 'Mini Gifts Distributors Ltd.', 10142, 5),
#  (124, 'Mini Gifts Distributors Ltd.', 10368, 5),
#  (124, 'Mini Gifts Distributors Ltd.', 10396, 5),
#  (129, 'Mini Wheels Co.', 10111, 5),
#  (157, 'Diecast Classics Inc.', 10318, 5),
#  (161, 'Technics Stores Inc.', 10362, 5),
#  (181, 'Vitachrome Inc.', 10237, 5),
#  (198, 'Auto-Moto Classics Inc.', 10130, 5),
#  (219, 'Boards & Toys Co.', 10376, 5),
#  (233, 'Québec Home Shopping Network', 10261, 5),
#  (233, 'Québec Home Shopping Network', 10411, 5),
#  (239, 'Collectable Mini Designs Co.', 10226, 5),
#  (319, 'Mini Classics', 10308, 5),
#  (363, 'Online Diecast Creations Co.', 10192, 5),
#  (424, 'Classic Legends Inc.', 10337, 5),
#  (447, 'Gift Ideas Corp.', 10131, 5),
#  (455, 'Super Scale Inc.', 10196, 5),
#  (455, 'Super Scale Inc.', 10245, 5),
#  (456, 'Microscale Inc.', 10242, 5),
#  (475, 'West Coast Collectables Co.', 10199, 5),
#  (486, 'Motor Mint Distributors Inc.', 10236, 5),
#  (487, 'Signal Collectibles Ltd.', 10149, 5),
#  (112, 'Signal Gift Stores', 10124, 4),
#  (124, 'Mini Gifts Distributors Ltd.', 10335, 4),
#  (124, 'Mini Gifts Distributors Ltd.', 10357, 4),
#  (157, 'Diecast Classics Inc.', 10281, 4),
#  (161, 'Technics Stores Inc.', 10168, 4),
#  (175, 'Gift Depot Inc.', 10263, 4),
#  (175, 'Gift Depot Inc.', 10413, 4),
#  (181, 'Vitachrome Inc.', 10102, 4),
#  (204, 'Online Mini Collectables', 10294, 4),
#  (205, 'Toys4GrownUps.com', 10367, 4),
#  (260, 'Royal Canadian Collectables, Ltd.', 10235, 4),
#  (286, "Marta's Replicas Co.", 10285, 4),
#  (320, 'Mini Creations Ltd.', 10365, 4),
#  (321, 'Corporate Gift Ideas Co.', 10384, 4),
#  (328, 'Tekni Collectables Inc.', 10233, 4),
#  (362, 'Gifts4AllAges.com', 10295, 4),
#  (363, 'Online Diecast Creations Co.', 10100, 4),
#  (379, 'Collectables For Less Inc.', 10147, 4),
#  (379, 'Collectables For Less Inc.', 10369, 4),
#  (424, 'Classic Legends Inc.', 10163, 4),
#  (450, 'The Sharp Gifts Warehouse', 10250, 4),
#  (112, 'Signal Gift Stores', 10278, 3),
#  (124, 'Mini Gifts Distributors Ltd.', 10271, 3),
#  (124, 'Mini Gifts Distributors Ltd.', 10390, 3),
#  (131, 'Land of Toys Inc.', 10292, 3),
#  (151, 'Muscle Machine Inc', 10127, 3),
#  (173, 'Cambridge Collectables Co.', 10228, 3),
#  (173, 'Cambridge Collectables Co.', 10249, 3),
#  (181, 'Vitachrome Inc.', 10324, 3),
#  (202, 'Canadian Gift Exchange Network', 10206, 3),
#  (202, 'Canadian Gift Exchange Network', 10313, 3),
#  (260, 'Royal Canadian Collectables, Ltd.', 10283, 3),
#  (319, 'Mini Classics', 10195, 3),
#  (347, "Men 'R' US Retailers, Ltd.", 10209, 3),
#  (424, 'Classic Legends Inc.', 10115, 3),
#  (447, 'Gift Ideas Corp.', 10146, 3),
#  (450, 'The Sharp Gifts Warehouse', 10400, 3),
#  (456, 'Microscale Inc.', 10319, 3),
#  (462, 'FunGiftIdeas.com', 10321, 3),
#  (475, 'West Coast Collectables Co.', 10215, 3),
#  (124, 'Mini Gifts Distributors Ltd.', 10282, 2),
#  (124, 'Mini Gifts Distributors Ltd.', 10312, 2),
#  (124, 'Mini Gifts Distributors Ltd.', 10371, 2),
#  (129, 'Mini Wheels Co.', 10333, 2),
#  (131, 'Land of Toys Inc.', 10107, 2),
#  (151, 'Muscle Machine Inc', 10204, 2),
#  (151, 'Muscle Machine Inc', 10267, 2),
#  (151, 'Muscle Machine Inc', 10349, 2),
#  (157, 'Diecast Classics Inc.', 10272, 2),
#  (233, 'Québec Home Shopping Network', 10171, 2),
#  (286, "Marta's Replicas Co.", 10305, 2),
#  (320, 'Mini Creations Ltd.', 10143, 2),
#  (339, 'Classic Gift Ideas, Inc', 10183, 2),
#  (487, 'Signal Collectibles Ltd.', 10219, 2),
#  (495, 'Diecast Collectables', 10207, 2),
#  (495, 'Diecast Collectables', 10243, 2),
#  (112, 'Signal Gift Stores', 10346, 1),
#  (124, 'Mini Gifts Distributors Ltd.', 10113, 1),
#  (124, 'Mini Gifts Distributors Ltd.', 10135, 1),
#  (124, 'Mini Gifts Distributors Ltd.', 10229, 1),
#  (124, 'Mini Gifts Distributors Ltd.', 10382, 1),
#  (124, 'Mini Gifts Distributors Ltd.', 10385, 1),
#  (129, 'Mini Wheels Co.', 10201, 1),
#  (131, 'Land of Toys Inc.', 10329, 1),
#  (239, 'Collectable Mini Designs Co.', 10222, 1),
#  (321, 'Corporate Gift Ideas Co.', 10162, 1),
#  (321, 'Corporate Gift Ideas Co.', 10381, 1),
#  (362, 'Gifts4AllAges.com', 10264, 1),
#  (379, 'Collectables For Less Inc.', 10274, 1),
#  (447, 'Gift Ideas Corp.', 10353, 1),
#  (450, 'The Sharp Gifts Warehouse', 10257, 1),
#  (486, 'Motor Mint Distributors Inc.', 10109, 1)]

# %% [markdown]
# ## S4

# %% [markdown]
# - In almost all cases, the ```scale``` of a ```products``` is encoded in the ```productCode.```
#
#
# - For example,

# %%
# %sql select productCode, productScale from classicmodels.products limit 5;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 5 rows affected.
# [('S10_1678', '1:10'),
#  ('S10_1949', '1:10'),
#  ('S10_2016', '1:10'),
#  ('S10_4698', '1:10'),
#  ('S10_4757', '1:10')]

# %% [markdown]
# - There are, however, some cases where this is not true. Produce the following table.

# %%
# %%sql
# select * from classicmodels.midterm_s4;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 6 rows affected.
# [('18', '12', 'S12_3148', '1:18'),
#  ('72', '18', 'S18_2581', '1:72'),
#  ('18', '24', 'S24_3856', '1:18'),
#  ('18', '24', 'S24_4620', '1:18'),
#  ('18', '700', 'S700_2824', '1:18'),
#  ('72', '700', 'S700_3167', '1:72')]

# %%
# %%sql
# use classicmodels;
# with product_form as(
# select SUBSTRING_INDEX(productScale, ':',-1)as scale_in_product_scale, SUBSTRING_INDEX(SUBSTRING_INDEX(productCode,'S',-1),'_',1) as scale_in_product_Number, productCode, productScale from products)
# select*from product_form where not scale_in_product_scale = scale_in_product_Number;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 6 rows affected.
# [('18', '12', 'S12_3148', '1:18'),
#  ('72', '18', 'S18_2581', '1:72'),
#  ('18', '24', 'S24_3856', '1:18'),
#  ('18', '24', 'S24_4620', '1:18'),
#  ('18', '700', 'S700_2824', '1:18'),
#  ('72', '700', 'S700_3167', '1:72')]

# %% [markdown]
# # Data Loading and Cleanup

# %% [markdown]
# ## DL1

# %% [markdown]
# - There is a file ```course_info.csv``` in the directory/folder for the midterm.
#
#
# - Do not ask how I got this information, but it looked something like this ... ...
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - The following code reads the JSON file and displays some of the data.

# %%
df = pd.read_csv("course_info.csv")
df
# Out:
#        Unnamed: 0  ExamDate   Term ChargeAmt1 Meets4 TypeCode SubtermCode  \
# 0               0       NaN  20212        NaN    NaN       LC         NaN
# 1               1       NaN  20212        NaN    NaN       LC         NaN
# 2               2       NaN  20212        NaN    NaN       LC         NaN
# 3               3       NaN  20212        NaN    NaN       LC         NaN
# 4               4       NaN  20212        NaN    NaN       LC         NaN
# ...           ...       ...    ...        ...    ...      ...         ...
# 21430       21430       NaN  20222        NaN    NaN       RG           L
# 21431       21431       NaN  20222        NaN    NaN       RG           K
# 21432       21432       NaN  20222        NaN    NaN       RG           L
# 21433       21433       NaN  20222     100.00    NaN       LC           K
# 21434       21434       NaN  20222     100.00    NaN       LC           L
#
#       CampusCode        Course Instructor3Name  ...  MaxUnits  \
# 0           MORN  ACCT5001BXMT             NaN  ...         0
# 1           MORN  ACCT5001B001             NaN  ...         0
# 2           MORN  ACCT5001B002             NaN  ...         0
# 3           MORN  ACCT5001B300             NaN  ...         0
# 4           MORN  ACCT5001B400             NaN  ...         0
# ...          ...           ...             ...  ...       ...
# 21430       MORN  WRTG0100K002             NaN  ...         0
# 21431       MORN  WRTI0100K001             NaN  ...         0
# 21432       MORN  WRTI0100K002             NaN  ...         0
# 21433       MORN  ZOO 0100K001             NaN  ...         0
# 21434       MORN  ZOO 0100K002             NaN  ...         0
#
#                            SchoolName       Instructor2Name  Meets6 MinUnits  \
# 0         Graduate School Of Business                   NaN     NaN        0
# 1         Graduate School Of Business                   NaN     NaN        0
# 2         Graduate School Of Business                   NaN     NaN        0
# 3         Graduate School Of Business                   NaN     NaN        0
# 4         Graduate School Of Business  SOURSOURIAN, JESSICA     NaN        0
# ...                               ...                   ...     ...      ...
# 21430  School Of Professional Studies                   NaN     NaN        0
# 21431  School Of Professional Studies                   NaN     NaN        0
# 21432  School Of Professional Studies                   NaN     NaN        0
# 21433  School Of Professional Studies                   NaN     NaN        0
# 21434  School Of Professional Studies                   NaN     NaN        0
#
#       DepartmentCode          ChargeMsg1      TypeName  \
# 0               ACCT                 NaN       LECTURE
# 1               ACCT                 NaN       LECTURE
# 2               ACCT                 NaN       LECTURE
# 3               ACCT                 NaN       LECTURE
# 4               ACCT                 NaN       LECTURE
# ...              ...                 ...           ...
# 21430           SHSP                 NaN  REGISTRATION
# 21431           SHSP                 NaN  REGISTRATION
# 21432           SHSP                 NaN  REGISTRATION
# 21433           SHSP  Biological Conserv       LECTURE
# 21434           SHSP  Biological Conserv       LECTURE
#
#                   CourseSubtitle                                    Meets1
# 0           Financial Accounting                                       NaN
# 1           Financial Accounting  S      09:00A-10:15ABTBA            RTBA
# 2           Financial Accounting  S      09:00A-10:15ABTBA            RTBA
# 3           Financial Accounting  MW     09:00A-10:15ABTBA            RTBA
# 4           Financial Accounting  TS     09:00A-10:15ABTBA            RTBA
# ...                          ...                                       ...
# 21430  Intro to Creative Writing                                       NaN
# 21431  Creative Writing: Introdu                                       NaN
# 21432  Creative Writing: Introdu                                       NaN
# 21433     Inside the Animal Mind  MTWRF  11:10A-01:00PBTBA            RTBA
# 21434     Inside the Animal Mind  MTWRF  11:10A-01:00PBTBA            RTBA
#
# [21435 rows x 45 columns]

# %% [markdown]
# - The list of columns in the data is:

# %%
for c in df.columns:
    print(c)
# Out:
# Unnamed: 0
# ExamDate
# Term
# ChargeAmt1
# Meets4
# TypeCode
# SubtermCode
# CampusCode
# Course
# Instructor3Name
# ChargeAmt2
# CallNumber
# CourseTitle
# NumFixedUnits
# Instructor1Name
# DivisionName
# MaxSize
# Instructor4Name
# Meets2
# SchoolCode
# ChargeMsg2
# SubtermName
# Approval
# BulletinFlags
# PrefixName
# PrefixLongname
# EnrollmentStatus
# CampusName
# Meets5
# ClassNotes
# DivisionCode
# ExamMeet
# DepartmentName
# NumEnrolled
# Meets3
# MaxUnits
# SchoolName
# Instructor2Name
# Meets6
# MinUnits
# DepartmentCode
# ChargeMsg1
# TypeName
# CourseSubtitle
# Meets1

# %% [markdown]
# - And you can find out the meaning of the columns on [CU's Open Data site.](https://opendataservice.columbia.edu/doc)
#
# ```
# "Term": Five digit term code, year then semester 1=Spring, 2=Summer, 3=Fall. (e.g. 20131 = Spring 2013)
#     "Course": Subject, Course and Section number
#     "PrefixName":
#     "DivisionCode": Code of the division providing the course
#     "DivisionName": Name of the division providing the course
#     "CampusCode": Code of the campus the course is on
#     "CampusName": Name of the campus the course is on
#     "SchoolCode": Code of the school providing the course
#     "SchoolName": Name of the school providing the course
#     "DepartmentCode": Code of the department providing the course
#     "DepartmentName": Name of the department providing the course
#     "SubtermCode":
#     "SubtermName":
#     "CallNumber": Registration call number of the couse
#     "NumEnrolled": number currently enrolled
#     "MaxSize": max enrollment size
#     "EnrollmentStatus": O=Open C=Closed
#     "NumFixedUnits": default credits for the course
#     "MinUnits":
#     "MaxUnits":
#     "CourseTitle": Title of the couse
#     "CourseSubtitle": Subtitle of the course
#     "TypeCode": "LC",
#     "TypeName": "LECTURE",
#     "Approval": if approval is needed
#     "BulletinFlags": "B",
#     "ClassNotes": "",
#     "Meets1": "",
#     "Meets2": "",
#     "Meets3": "",
#     "Meets4": "",
#     "Meets5": "",
#     "Meets6": "",
#     "Instructor1Name": "NISSIM, DORON",
#     "Instructor2Name": "",
#     "Instructor3Name": "",
#     "Instructor4Name": "",
#     "PrefixLongname": "ACCOUNTING",
#     "ExamMeet": "",
#     "ExamDate": "",
#     "ChargeMsg1": "",
#     "ChargeAmt1": "",
#     "ChargeMsg2": "",
#     "ChargeAmt2": ""
# ```

# %% [markdown]
# - Now, while laughing diabolically, I had started to write a question asking you to create a schema, factor the data into multiple tables, clean up the data and set types, set keys and constraints, etc.
#
#
# - Performing the work to answer this question took me two hours. I find that students typical need 10X as much time as I need. The diabolical Riddler laughter really took off when I was done.
#
#
# - But, something a lot like this happened. ... ...
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - So, I deleted the question and decided to make it one of the extra-credit assignments later in the semester.
#
#
# - Do not worry about this question now. I will publish as extra-credit later in the semester.

# %% [markdown]
# # Putting it All Together
#
# ## A1

# %% [markdown]
# - Sadly for you, Batman seems to think I learned my lesson and can be trusted to define reasonable questions. We all know that is not true. So, when you think about it, this horrible question is at least partly Batman's fault.
#
#
# - The midterm directory contains a file ```people_info.csv.``` The columns are:
#     - ```first_name```
#     - ```middle_name```
#     - ```last_name```
#     - ```email```
#     - ```employee_type,``` which can be one of ```Professor, Lecturer, Staff.``` The value is empty of the person is a student.
#     - ```enrollment_year``` which must be in the range ```2016 - 2022.``` The value is empty of the person is an employee.
#
#
# - If ```enrollment_year``` is NULL, the person is a ```Student``` and ```employee_type``` must be NULL. If ```employee_type``` is not NULL, then the person is NOT a student and ```enrollment_year``` must be NULL.
#
#
# - You must implement a [two-table](https://vertabelo.com/blog/inheritance-in-a-relational-database/) solution to the inheritance pattern. This means that your solution will have tables ```students``` and ```employees,``` and will have a view ```people.```
#
#
# - Your solution must implement the following tasks and meet the following criteria.
#     1. You must implement the two tables and views, including reasonable data types and constraints. This must include an additional column ```uni``` that we explain below. You may have additional columns if that helps.
#     2. You must implement four stored procedures. The implementations of the four procedures are almost identical.
#         1. The procedures are:
#             1. create_student(first_name, middle_name, last_name, email, enrollment_year, uni, guid)
#             2. create_employee(first_name, middle_name, last_name, email, employee_type, uni, guid)
#             3. update_student(uni, first_name, middle_name, last_name, email, enrollment_year)
#             4. update_employee(uni, first_name, middle_name, last_name, email, employee_type)
#         2. For updates, the procedures ignore input parameters that are NULL and only apply the non-NULL values. The procedure does not update the ```uni.```
#         3. The create procedures must generate the value for the ```GUID``` and ```uni``` and return them as out values.
#     3. ```employee_type``` must be one of ```Professor, Lecturer, Staff.```
#     4. ```enrollment_year``` must be in the range ```2016 - 2022``` inclusive.
#     5. Only ```middle_name``` can be null.
#     3. uni:
#         1. Must be of the form "FMLnnnn" where "F" is the first letter of the first name, "M" is the first letter of the middle_name (if not NULL), "L" is the first letter of the last name.
#         2. For any combination of letters, the numbers following the letters must start at 1 and increase. That is "DFF1", "AB1", "DFF2", "CD1", "CAD1", "CD2", ... ...
#         3. You must implement a function to generate the ```uni``` and a trigger on the relevant tables to automatically set the ```uni``` and ```GUID``` on INSERT. You must implement a trigger that prevents changing the ```uni``` or ```GUID.```
#     4. ```email``` must be unique over both ```student``` and ```employee.```
#     3. You must use security to disable calling ```INSERT, DELETE``` and ```UPDATE``` on the underlying tables for any user other than ```root``` or ```dbuser.``` You must test this by creating an additional user ```general_user``` and connecting as that user.
#
#
# - You must demonstrate correct implementation by loading the data, using select statements, attempting insert/update/delete, ... ...
#
#
# - The following code will load the tables for you if you have properly implemented the tables and functions.
#
#
# - The execution also helps you understand how to test procedures, etc.

# %%
# %%sql
#
# create schema if not exists dff9_s22_midterm;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# []

# %%
# %%sql
# use dff9_s22_midterm;
# drop table students;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# Put your create table, procedure, functions, etc. definitions int he following cells.
#

# %%
# %%sql
# use dff9_s22_midterm;
# create table students
# (
#     first_name varchar(255) not null,
#     middle_name varchar(255),
#     last_name varchar(255) not null,
#     email varchar(255),
#     enrollment_year int(255),
#     uni int(255),
#     UNIQUE(email),
#     guid varchar(64),
#     CHECK (enrollment_year>=2016 and enrollment_year <=2022)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# use dff9_s22_midterm;
# drop table employees;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# use dff9_s22_midterm;
# create table employees
# (
#     first_name varchar(255) not null,
#     middle_name varchar(255) not null,
#     last_name varchar(255),
#     email varchar(255),
#     employee_type varchar(255),
#     guid varchar(255),
#     uni varchar(255)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE employees
# ADD CONSTRAINT CHK_type CHECK (employee_type ='Professor' or employee_type ='Lecturer'or employee_type='Faculty');
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE VIEW people AS
# select guid as id, first_name, middle_name, last_name, email,uni from students
# union all
# select guid as id, first_name, middle_name, last_name,email,uni from employees;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# CREATE PROCEDURE SelectAllCustomers @City nvarchar(30)
# AS
# SELECT * FROM Customers WHERE City = @City
# GO;

# %%
# The following only works if you have already created the tables, procedures, etc.
# So, you mus have answered the questions to run the load.
#
# %sql use dff9_s22_midterm;
# %sql delete from student;
# %sql delete from employee;
# %sql select 1;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 0 rows affected.
#  * mysql+pymysql://dbuser:***@localhost
# 50 rows affected.
#  * mysql+pymysql://dbuser:***@localhost
# 50 rows affected.
#  * mysql+pymysql://dbuser:***@localhost
# 1 rows affected.
# [(1,)]

# %%
# Load the information from the file and show sample values.
import csv

people_info = []
with open("people_info.csv", "r") as in_file:
    d_rdr = csv.DictReader(in_file)
    for r in d_rdr:
        people_info.append(dict(r))

people_info_df = pd.DataFrame(people_info)
people_info_df
# Out:
#    first_name middle_name  last_name                           email  \
# 0     Sanders      Arline   Breckell           abreckell1x@fotki.com
# 1       Zared                Fenelon       afenelona@themeforest.net
# 2     Ethelin                 Fidele             afidele12@google.ru
# 3      Bibbye     Annabal   Guesford           aguesfordb@tumblr.com
# 4       Xenia     Ardella       Kief                  akieft@free.fr
# ..        ...         ...        ...                             ...
# 95      Norry              Rubinchik  trubinchik16@howstuffworks.com
# 96       Doug               Medforth       vmedforth1o@homestead.com
# 97      Gerty              O'Donegan        vodoneganf@clickbank.net
# 98   Anabelle      Wallas     Quimby               wquimby1c@nba.com
# 99      Sasha         Win     Ruffli         wruffli2q@wordpress.com
#
#    employee_type enrollment_year
# 0      Professor
# 1                           2021
# 2       Lecturer
# 3                           2018
# 4          Staff
# ..           ...             ...
# 95                          2016
# 96         Staff
# 97                          2020
# 98                          2022
# 99      Lecturer
#
# [100 rows x 6 columns]

# %%
people_info[-5:]

# %%
# If you have defined your procedures, functions, tables and constraints correctly, you can use the function below
# to load your data.
#
import copy

def add_person(p):
    """
    p is a dictionary containing the column values for either a student or an employee.
    """
    
    cur = sql_conn.cursor()
    
    # This function changes the data, converting '' to None.
    # So, we make a copy and change the copy.
    p_dict = copy.copy(p)
    for k,v in p_dict.items():
        if v == '':
            p_dict[k] = None
    
    # Is the person a student?
    #
    if p_dict['employee_type'] is None:
        
        # This provides a hint for what your stored procedure will look like.
        res = cur.callproc("dff9_s22_midterm.create_student",
                           # The following are in parameters
                          (p_dict['first_name'],
                          p_dict['middle_name'],
                          p_dict['last_name'],
                           p_dict['email'],
                          p_dict['enrollment_year'],
                           # The following are out parameters for uni and GUID.
                          None,
                          None))
        
        # After the procedure executes, the following query will select the out values.
        res = cur.execute("""SELECT @_dff9_s22_midterm.create_student_5,
                              @_dff9_s22_midterm.create_student_6""")
        result = cur.fetchall()
    
    # The following does the same for employee.
    elif p_dict['enrollment_year'] is None:
        res = cur.callproc("dff9_s22_midterm.create_employee",
                          (p_dict['first_name'],
                          p_dict['middle_name'],
                          p_dict['last_name'],
                           p_dict['email'],
                          p_dict['employee_type'],
                          None,
                          None))
        res = cur.execute("""SELECT @_dff9_s22_midterm.create_student_5,
                              @_dff9_s22_midterm.create_student_6""")
        result = cur.fetchall()
    else:
        print("Huh")
        result = None
    
    sql_conn.commit()
    cur.close()
    return result

# %%
for p in people_info:
    add_person(p)

# %%
#
# Test that we loaded people.
#
# %sql select * from people;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 100 rows affected.
# [('103e6a74-a882-11ec-a3ad-edb7cbd2bb34', 'SAB1', 'Sanders', 'Arline', 'Breckell', 'abreckell1x@fotki.com'),
#  ('103f2a54-a882-11ec-a3ad-edb7cbd2bb34', 'EF1', 'Ethelin', None, 'Fidele', 'afidele12@google.ru'),
#  ('103fa696-a882-11ec-a3ad-edb7cbd2bb34', 'XAK1', 'Xenia', 'Ardella', 'Kief', 'akieft@free.fr'),
#  ('103fe1ec-a882-11ec-a3ad-edb7cbd2bb34', 'CAL1', 'Cari', 'Andriana', 'Leask', 'aleask1n@devhub.com'),
#  ('10409f88-a882-11ec-a3ad-edb7cbd2bb34', 'LBB1', 'Lemmy', 'Burr', 'Bradnocke', 'bbradnockek@nifty.com'),
#  ('10411828-a882-11ec-a3ad-edb7cbd2bb34', 'SBL1', 'Sibylle', 'Bearnard', 'Lalley', 'blalley2d@rediff.com'),
#  ('1041cc50-a882-11ec-a3ad-edb7cbd2bb34', 'LCF1', 'Lu', 'Cinnamon', 'Flaxman', 'cflaxman1b@cdbaby.com'),
#  ('1043122c-a882-11ec-a3ad-edb7cbd2bb34', 'HDC1', 'Hobart', 'Dominic', 'Croal', 'dcroalx@purevolume.com'),
#  ('10434364-a882-11ec-a3ad-edb7cbd2bb34', 'MDF1', 'Marylin', 'Darcy', 'Favey', 'dfavey2p@mozilla.com'),
#  ('1043a598-a882-11ec-a3ad-edb7cbd2bb34', 'ADW1', 'Ailbert', 'Danie', 'Warmisham', 'dwarmishame@soundcloud.com'),
#  ('10440c22-a882-11ec-a3ad-edb7cbd2bb34', 'KB1', 'Karon', None, 'Bree', 'ebree1z@creativecommons.org'),
#  ('10448a62-a882-11ec-a3ad-edb7cbd2bb34', 'MEC1', 'Maybelle', 'Esteban', 'Cella', 'ecella26@mail.ru'),
#  ('1044d36e-a882-11ec-a3ad-edb7cbd2bb34', 'LEF1', 'Lelah', 'Ellette', 'Fulk', 'efulk1d@discuz.net'),
#  ('10471598-a882-11ec-a3ad-edb7cbd2bb34', 'GB1', 'Gisela', None, 'Blagden', 'gblagden1q@buzzfeed.com'),
#  ('10479086-a882-11ec-a3ad-edb7cbd2bb34', 'NGF1', 'Niki', 'Gardiner', 'Form', 'gform18@blogger.com'),
#  ('1047c452-a882-11ec-a3ad-edb7cbd2bb34', 'SH1', 'Suki', None, 'Hellyar', 'ghellyar2a@cornell.edu'),
#  ('10486628-a882-11ec-a3ad-edb7cbd2bb34', 'CT1', 'Carmine', None, 'Tolman', 'gtolmanr@slideshare.net'),
#  ('10489936-a882-11ec-a3ad-edb7cbd2bb34', 'WY1', 'Wells', None, 'Yousef', 'gyousef2r@spotify.com'),
#  ('1049298c-a882-11ec-a3ad-edb7cbd2bb34', 'CS1', 'Christie', None, 'Siegertsz', 'hsiegertsz21@instagram.com'),
#  ('10495588-a882-11ec-a3ad-edb7cbd2bb34', 'DA2', 'Doyle', None, 'Aslin', 'jaslin24@redcross.org'),
#  ('104989f4-a882-11ec-a3ad-edb7cbd2bb34', 'RJC1', 'Robinett', 'Jami', 'Charte', 'jcharte1y@merriam-webster.com'),
#  ('1049b9f6-a882-11ec-a3ad-edb7cbd2bb34', 'OH1', 'Olwen', None, 'Hedley', 'jhedley1m@disqus.com'),
#  ('104a4b96-a882-11ec-a3ad-edb7cbd2bb34', 'RJP1', 'Renae', 'Jaquith', 'Plessing', 'jplessing0@samsung.com'),
#  ('104ad9e4-a882-11ec-a3ad-edb7cbd2bb34', 'LS1', 'Lilllie', None, 'Snodin', 'jsnodin20@princeton.edu'),
#  ('104b39de-a882-11ec-a3ad-edb7cbd2bb34', 'SKM1', 'Sayers', 'Karon', 'McKnish', 'kmcknishs@reddit.com'),
#  ('104b6ee0-a882-11ec-a3ad-edb7cbd2bb34', 'EKM1', 'Electra', 'Krystle', 'Morfell', 'kmorfell2g@istockphoto.com'),
#  ('104b9cda-a882-11ec-a3ad-edb7cbd2bb34', 'MKS1', 'Matthieu', 'Kalle', 'Slipper', 'kslipper2f@nytimes.com'),
#  ('104bd38a-a882-11ec-a3ad-edb7cbd2bb34', 'NT1', 'Nadia', None, 'Trehearn', 'ktrehearn19@tinyurl.com'),
#  ('104c009e-a882-11ec-a3ad-edb7cbd2bb34', 'CG1', 'Clim', None, 'Guislin', 'lguislin2o@chicagotribune.com'),
#  ('104c5eae-a882-11ec-a3ad-edb7cbd2bb34', 'HH1', 'Holli', None, 'Henstridge', 'lhenstridgeh@sogou.com'),
#  ('104c902c-a882-11ec-a3ad-edb7cbd2bb34', 'MK2', 'Meghan', None, 'Kleinschmidt', 'lkleinschmidtl@squarespace.com'),
#  ('104cbcaa-a882-11ec-a3ad-edb7cbd2bb34', 'GP1', 'Genni', None, 'Purbrick', 'lpurbrick25@canalblog.com'),
#  ('104ce9c8-a882-11ec-a3ad-edb7cbd2bb34', 'BS1', 'Bonny', None, 'Scheffel', 'lscheffel7@taobao.com'),
#  ('104d14ca-a882-11ec-a3ad-edb7cbd2bb34', 'MT1', 'Mendie', None, 'Tennick', 'ltennick3@aboutads.info'),
#  ('104d6c04-a882-11ec-a3ad-edb7cbd2bb34', 'KI1', 'Karole', None, 'Inkin', 'minkinc@google.de'),
#  ('104dcb9a-a882-11ec-a3ad-edb7cbd2bb34', 'KMP1', 'Kahaleel', 'Meg', 'Penzer', 'mpenzer14@dailymail.co.uk'),
#  ('104e268a-a882-11ec-a3ad-edb7cbd2bb34', 'DMW1', 'Darrin', 'Mario', 'Wynrahame', 'mwynrahamem@admin.ch'),
#  ('104e64b0-a882-11ec-a3ad-edb7cbd2bb34', 'CMW1', 'Carey', 'Maudie', 'Wyrall', 'mwyrallj@scientificamerican.com'),
#  ('104e98ea-a882-11ec-a3ad-edb7cbd2bb34', 'JNB1', 'Jacky', 'Nydia', 'Bolles', 'nbolles23@ucoz.ru'),
#  ('104ed44a-a882-11ec-a3ad-edb7cbd2bb34', 'FM1', 'Francene', None, 'MacNeely', 'nmacneely22@cpanel.net'),
#  ('105016e8-a882-11ec-a3ad-edb7cbd2bb34', 'BRM1', 'Bamby', 'Rubetta', 'Mabbs', 'rmabbs4@xing.com'),
#  ('1050566c-a882-11ec-a3ad-edb7cbd2bb34', 'ARS1', 'Ari', 'Rheta', 'Sellek', 'rsellek6@oakley.com'),
#  ('10513686-a882-11ec-a3ad-edb7cbd2bb34', 'BSH1', 'Bettina', 'Sonya', 'Higgonet', 'shiggonet2b@163.com'),
#  ('10516af2-a882-11ec-a3ad-edb7cbd2bb34', 'JSJ1', 'Jany', 'Sherry', 'Johl', 'sjohlg@soundcloud.com'),
#  ('105199d2-a882-11ec-a3ad-edb7cbd2bb34', 'PL1', 'Pattie', None, 'Lyles', 'slyles1j@amazon.de'),
#  ('1051c8d0-a882-11ec-a3ad-edb7cbd2bb34', 'KM2', 'Kristin', None, 'Malacrida', 'smalacrida1w@economist.com'),
#  ('1052055c-a882-11ec-a3ad-edb7cbd2bb34', 'YSM1', 'Yehudi', 'Sile', 'McColley', 'smccolleyq@amazon.com'),
#  ('10525aca-a882-11ec-a3ad-edb7cbd2bb34', 'DSS1', 'Duncan', 'Shellie', 'Sillars', 'ssillars2l@unicef.org'),
#  ('10531bd6-a882-11ec-a3ad-edb7cbd2bb34', 'DM3', 'Doug', None, 'Medforth', 'vmedforth1o@homestead.com'),
#  ('1053a128-a882-11ec-a3ad-edb7cbd2bb34', 'SWR1', 'Sasha', 'Win', 'Ruffli', 'wruffli2q@wordpress.com'),
#  ('103edf18-a882-11ec-a3ad-edb7cbd2bb34', 'ZF1', 'Zared', None, 'Fenelon', 'afenelona@themeforest.net'),
#  ('103f6b22-a882-11ec-a3ad-edb7cbd2bb34', 'BAG1', 'Bibbye', 'Annabal', 'Guesford', 'aguesfordb@tumblr.com'),
#  ('10402f4e-a882-11ec-a3ad-edb7cbd2bb34', 'DAP1', 'Duffy', 'Auberon', 'Pounder', 'apounder2h@reuters.com'),
#  ('10406b1c-a882-11ec-a3ad-edb7cbd2bb34', 'BB1', 'Base', None, 'Baybutt', 'bbaybutty@tmall.com'),
#  ('1040de26-a882-11ec-a3ad-edb7cbd2bb34', 'JBH1', 'Jenine', 'Berry', 'Habberjam', 'bhabberjam2k@examiner.com'),
#  ('104153d8-a882-11ec-a3ad-edb7cbd2bb34', 'RCC1', 'Reece', 'Corbett', 'Caps', 'ccapsz@telegraph.co.uk'),
#  ('10419168-a882-11ec-a3ad-edb7cbd2bb34', 'BCE1', 'Barry', 'Cullin', 'Elias', 'celias1k@scribd.com'),
#  ('104203d2-a882-11ec-a3ad-edb7cbd2bb34', 'KCF1', 'Kerwin', 'Conrade', 'Foort', 'cfoortw@vinaora.com'),
#  ('1042383e-a882-11ec-a3ad-edb7cbd2bb34', 'BCM1', 'Brigida', 'Cameron', 'Maclean', 'cmaclean13@mac.com'),
#  ('10426bc4-a882-11ec-a3ad-edb7cbd2bb34', 'WCM1', 'Woodrow', 'Camile', 'Moughtin', 'cmoughtin17@illinois.edu'),
#  ('1042a7b0-a882-11ec-a3ad-edb7cbd2bb34', 'VCS1', 'Veronika', 'Cordey', 'Simeons', 'csimeons2@microsoft.com'),
#  ('1042da5a-a882-11ec-a3ad-edb7cbd2bb34', 'QT1', 'Quent', None, 'Threadgall', 'cthreadgall1v@booking.com'),
#  ('1043741a-a882-11ec-a3ad-edb7cbd2bb34', 'KG1', 'Kermit', None, 'Glanders', 'dglanders15@booking.com'),
#  ('1043d770-a882-11ec-a3ad-edb7cbd2bb34', 'AEB1', 'Avie', 'Else', 'Blissitt', 'eblissitti@youtu.be'),
#  ('10443e04-a882-11ec-a3ad-edb7cbd2bb34', 'DB1', 'Dougy', None, 'Burchett', 'eburchettd@chicagotribune.com'),
#  ('10450474-a882-11ec-a3ad-edb7cbd2bb34', 'CEG1', 'Courtnay', 'Elbert', 'Gillespie', 'egillespie2m@slideshare.net'),
#  ('10453412-a882-11ec-a3ad-edb7cbd2bb34', 'BEG1', 'Bank', 'Elane', 'Guerola', 'eguerola29@blogger.com'),
#  ('1045873c-a882-11ec-a3ad-edb7cbd2bb34', 'WK1', 'Willi', None, 'Kerby', 'ekerby1p@amazon.com'),
#  ('1045bcb6-a882-11ec-a3ad-edb7cbd2bb34', 'VEM1', 'Vincenty', 'Elisabeth', 'Marousek', 'emarousek10@huffingtonpost.com'),
#  ('1045f3b6-a882-11ec-a3ad-edb7cbd2bb34', 'CFH1', 'Charline', 'Ferd', 'Hartell', 'fhartell1@meetup.com'),
#  ('1046276e-a882-11ec-a3ad-edb7cbd2bb34', 'VM1', 'Vance', None, 'Maffioni', 'fmaffioni1r@amazon.com'),
#  ('10465d56-a882-11ec-a3ad-edb7cbd2bb34', 'DFR1', 'Dyna', 'Felic', 'Rozenzweig', 'frozenzweig2i@rambler.ru'),
#  ('104696ea-a882-11ec-a3ad-edb7cbd2bb34', 'GGA1', 'Granville', 'Guinevere', 'Adolphine', 'gadolphine11@instagram.com'),
#  ('1046e42e-a882-11ec-a3ad-edb7cbd2bb34', 'SGB1', 'Shea', 'Gail', 'Bates', 'gbates1e@alibaba.com'),
#  ('10474608-a882-11ec-a3ad-edb7cbd2bb34', 'LGB1', 'Leann', 'Gabriellia', 'Burdas', 'gburdas1i@indiegogo.com'),
#  ('1047f972-a882-11ec-a3ad-edb7cbd2bb34', 'TGO1', 'Tobiah', 'Gerek', 'Offield', 'goffield1u@addthis.com'),
#  ('10482e38-a882-11ec-a3ad-edb7cbd2bb34', 'SS1', 'Sada', None, 'Stidson', 'gstidsonp@ebay.com'),
#  ('1048c848-a882-11ec-a3ad-edb7cbd2bb34', 'AHA1', 'Abbey', 'Helge', 'Anyene', 'hanyene2c@newsvine.com'),
#  ('1048f7e6-a882-11ec-a3ad-edb7cbd2bb34', 'NHR1', 'Nickolai', 'Herby', 'Reddyhoff', 'hreddyhoff1g@vk.com'),
#  ('1049ebf6-a882-11ec-a3ad-edb7cbd2bb34', 'MJI1', 'Mal', 'Jermaine', 'Issett', 'jissett2e@freewebs.com'),
#  ('104a1bd0-a882-11ec-a3ad-edb7cbd2bb34', 'IL1', 'Ira', None, 'Linacre', 'jlinacreo@webnode.com'),
#  ('104a79a4-a882-11ec-a3ad-edb7cbd2bb34', 'TP1', 'Trix', None, 'Pretswell', 'jpretswell1h@xrea.com'),
#  ('104aa988-a882-11ec-a3ad-edb7cbd2bb34', 'WS1', 'Winslow', None, 'Scrauniage', 'jscrauniage28@aol.com'),
#  ('104b09a0-a882-11ec-a3ad-edb7cbd2bb34', 'DKC1', 'Dacey', 'Katuscha', 'Cranfield', 'kcranfield1s@nature.com'),
#  ('104c2f92-a882-11ec-a3ad-edb7cbd2bb34', 'ELH1', 'Emili', 'Lynnet', 'Haddinton', 'lhaddintonn@over-blog.com'),
#  ('104d3e78-a882-11ec-a3ad-edb7cbd2bb34', 'TMC1', 'Travis', 'Melba', 'Colbourne', 'mcolbourne2j@mapquest.com'),
#  ('104d974c-a882-11ec-a3ad-edb7cbd2bb34', 'LMI1', 'Lynett', 'Myrwyn', 'Ionesco', 'mionesco2n@moonfruit.com'),
#  ('104df57a-a882-11ec-a3ad-edb7cbd2bb34', 'RV1', 'Rozelle', None, 'Vigar', 'mvigar8@vistaprint.com'),
#  ('104f0280-a882-11ec-a3ad-edb7cbd2bb34', 'LOT1', 'Levey', 'Ottilie', 'Tomlins', 'otomlins27@icq.com'),
#  ('104f3b38-a882-11ec-a3ad-edb7cbd2bb34', 'ERC1', 'Esra', 'Richard', 'Coghlin', 'rcoghlinv@qq.com'),
#  ('104fdd04-a882-11ec-a3ad-edb7cbd2bb34', 'FRG1', 'Fredek', 'Raddie', 'Goudie', 'rgoudie5@blogs.com'),
#  ('10509348-a882-11ec-a3ad-edb7cbd2bb34', 'CV1', 'Carroll', None, 'Venables', 'rvenablesu@friendfeed.com'),
#  ('1050c6ce-a882-11ec-a3ad-edb7cbd2bb34', 'MRW1', 'Meridel', 'Rawley', 'Willatts', 'rwillatts1t@si.edu'),
#  ('1050fe00-a882-11ec-a3ad-edb7cbd2bb34', 'KSG1', 'Kearney', 'Selie', 'Gino', 'sgino1l@bluehost.com'),
#  ('10523298-a882-11ec-a3ad-edb7cbd2bb34', 'DM2', 'Drona', None, 'McKinie', 'smckinie1a@springer.com'),
#  ('1052850e-a882-11ec-a3ad-edb7cbd2bb34', 'SSS1', 'Sterne', 'Sasha', 'Spooner', 'sspooner1f@wordpress.org'),
#  ('1052b75e-a882-11ec-a3ad-edb7cbd2bb34', 'NG2', 'Nonna', None, 'Gillanders', 'tgillanders9@example.com'),
#  ('1052eb52-a882-11ec-a3ad-edb7cbd2bb34', 'NR1', 'Norry', None, 'Rubinchik', 'trubinchik16@howstuffworks.com'),
#  ('1053494e-a882-11ec-a3ad-edb7cbd2bb34', 'GO1', 'Gerty', None, "O'Donegan", 'vodoneganf@clickbank.net'),
#  ('1053740a-a882-11ec-a3ad-edb7cbd2bb34', 'AWQ1', 'Anabelle', 'Wallas', 'Quimby', 'wquimby1c@nba.com')]

# %%
#
# Test that we loaded students.
#
# %sql select * from student;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 50 rows affected.
# [('103edf18-a882-11ec-a3ad-edb7cbd2bb34', 'Zared', None, 'Fenelon', 'afenelona@themeforest.net', 'ZF1', 2021, 240),
#  ('103f6b22-a882-11ec-a3ad-edb7cbd2bb34', 'Bibbye', 'Annabal', 'Guesford', 'aguesfordb@tumblr.com', 'BAG1', 2018, 241),
#  ('10402f4e-a882-11ec-a3ad-edb7cbd2bb34', 'Duffy', 'Auberon', 'Pounder', 'apounder2h@reuters.com', 'DAP1', 2017, 242),
#  ('10406b1c-a882-11ec-a3ad-edb7cbd2bb34', 'Base', None, 'Baybutt', 'bbaybutty@tmall.com', 'BB1', 2021, 243),
#  ('1040de26-a882-11ec-a3ad-edb7cbd2bb34', 'Jenine', 'Berry', 'Habberjam', 'bhabberjam2k@examiner.com', 'JBH1', 2021, 244),
#  ('104153d8-a882-11ec-a3ad-edb7cbd2bb34', 'Reece', 'Corbett', 'Caps', 'ccapsz@telegraph.co.uk', 'RCC1', 2019, 245),
#  ('10419168-a882-11ec-a3ad-edb7cbd2bb34', 'Barry', 'Cullin', 'Elias', 'celias1k@scribd.com', 'BCE1', 2018, 246),
#  ('104203d2-a882-11ec-a3ad-edb7cbd2bb34', 'Kerwin', 'Conrade', 'Foort', 'cfoortw@vinaora.com', 'KCF1', 2020, 247),
#  ('1042383e-a882-11ec-a3ad-edb7cbd2bb34', 'Brigida', 'Cameron', 'Maclean', 'cmaclean13@mac.com', 'BCM1', 2019, 248),
#  ('10426bc4-a882-11ec-a3ad-edb7cbd2bb34', 'Woodrow', 'Camile', 'Moughtin', 'cmoughtin17@illinois.edu', 'WCM1', 2022, 249),
#  ('1042a7b0-a882-11ec-a3ad-edb7cbd2bb34', 'Veronika', 'Cordey', 'Simeons', 'csimeons2@microsoft.com', 'VCS1', 2021, 250),
#  ('1042da5a-a882-11ec-a3ad-edb7cbd2bb34', 'Quent', None, 'Threadgall', 'cthreadgall1v@booking.com', 'QT1', 2022, 251),
#  ('1043741a-a882-11ec-a3ad-edb7cbd2bb34', 'Kermit', None, 'Glanders', 'dglanders15@booking.com', 'KG1', 2022, 252),
#  ('1043d770-a882-11ec-a3ad-edb7cbd2bb34', 'Avie', 'Else', 'Blissitt', 'eblissitti@youtu.be', 'AEB1', 2018, 253),
#  ('10443e04-a882-11ec-a3ad-edb7cbd2bb34', 'Dougy', None, 'Burchett', 'eburchettd@chicagotribune.com', 'DB1', 2022, 254),
#  ('10450474-a882-11ec-a3ad-edb7cbd2bb34', 'Courtnay', 'Elbert', 'Gillespie', 'egillespie2m@slideshare.net', 'CEG1', 2020, 255),
#  ('10453412-a882-11ec-a3ad-edb7cbd2bb34', 'Bank', 'Elane', 'Guerola', 'eguerola29@blogger.com', 'BEG1', 2021, 256),
#  ('1045873c-a882-11ec-a3ad-edb7cbd2bb34', 'Willi', None, 'Kerby', 'ekerby1p@amazon.com', 'WK1', 2020, 257),
#  ('1045bcb6-a882-11ec-a3ad-edb7cbd2bb34', 'Vincenty', 'Elisabeth', 'Marousek', 'emarousek10@huffingtonpost.com', 'VEM1', 2020, 258),
#  ('1045f3b6-a882-11ec-a3ad-edb7cbd2bb34', 'Charline', 'Ferd', 'Hartell', 'fhartell1@meetup.com', 'CFH1', 2020, 259),
#  ('1046276e-a882-11ec-a3ad-edb7cbd2bb34', 'Vance', None, 'Maffioni', 'fmaffioni1r@amazon.com', 'VM1', 2020, 260),
#  ('10465d56-a882-11ec-a3ad-edb7cbd2bb34', 'Dyna', 'Felic', 'Rozenzweig', 'frozenzweig2i@rambler.ru', 'DFR1', 2022, 261),
#  ('104696ea-a882-11ec-a3ad-edb7cbd2bb34', 'Granville', 'Guinevere', 'Adolphine', 'gadolphine11@instagram.com', 'GGA1', 2017, 262),
#  ('1046e42e-a882-11ec-a3ad-edb7cbd2bb34', 'Shea', 'Gail', 'Bates', 'gbates1e@alibaba.com', 'SGB1', 2018, 263),
#  ('10474608-a882-11ec-a3ad-edb7cbd2bb34', 'Leann', 'Gabriellia', 'Burdas', 'gburdas1i@indiegogo.com', 'LGB1', 2021, 264),
#  ('1047f972-a882-11ec-a3ad-edb7cbd2bb34', 'Tobiah', 'Gerek', 'Offield', 'goffield1u@addthis.com', 'TGO1', 2020, 265),
#  ('10482e38-a882-11ec-a3ad-edb7cbd2bb34', 'Sada', None, 'Stidson', 'gstidsonp@ebay.com', 'SS1', 2022, 266),
#  ('1048c848-a882-11ec-a3ad-edb7cbd2bb34', 'Abbey', 'Helge', 'Anyene', 'hanyene2c@newsvine.com', 'AHA1', 2019, 267),
#  ('1048f7e6-a882-11ec-a3ad-edb7cbd2bb34', 'Nickolai', 'Herby', 'Reddyhoff', 'hreddyhoff1g@vk.com', 'NHR1', 2016, 268),
#  ('1049ebf6-a882-11ec-a3ad-edb7cbd2bb34', 'Mal', 'Jermaine', 'Issett', 'jissett2e@freewebs.com', 'MJI1', 2018, 269),
#  ('104a1bd0-a882-11ec-a3ad-edb7cbd2bb34', 'Ira', None, 'Linacre', 'jlinacreo@webnode.com', 'IL1', 2021, 270),
#  ('104a79a4-a882-11ec-a3ad-edb7cbd2bb34', 'Trix', None, 'Pretswell', 'jpretswell1h@xrea.com', 'TP1', 2022, 271),
#  ('104aa988-a882-11ec-a3ad-edb7cbd2bb34', 'Winslow', None, 'Scrauniage', 'jscrauniage28@aol.com', 'WS1', 2017, 272),
#  ('104b09a0-a882-11ec-a3ad-edb7cbd2bb34', 'Dacey', 'Katuscha', 'Cranfield', 'kcranfield1s@nature.com', 'DKC1', 2020, 273),
#  ('104c2f92-a882-11ec-a3ad-edb7cbd2bb34', 'Emili', 'Lynnet', 'Haddinton', 'lhaddintonn@over-blog.com', 'ELH1', 2020, 274),
#  ('104d3e78-a882-11ec-a3ad-edb7cbd2bb34', 'Travis', 'Melba', 'Colbourne', 'mcolbourne2j@mapquest.com', 'TMC1', 2017, 275),
#  ('104d974c-a882-11ec-a3ad-edb7cbd2bb34', 'Lynett', 'Myrwyn', 'Ionesco', 'mionesco2n@moonfruit.com', 'LMI1', 2020, 276),
#  ('104df57a-a882-11ec-a3ad-edb7cbd2bb34', 'Rozelle', None, 'Vigar', 'mvigar8@vistaprint.com', 'RV1', 2018, 277),
#  ('104f0280-a882-11ec-a3ad-edb7cbd2bb34', 'Levey', 'Ottilie', 'Tomlins', 'otomlins27@icq.com', 'LOT1', 2020, 278),
#  ('104f3b38-a882-11ec-a3ad-edb7cbd2bb34', 'Esra', 'Richard', 'Coghlin', 'rcoghlinv@qq.com', 'ERC1', 2019, 279),
#  ('104fdd04-a882-11ec-a3ad-edb7cbd2bb34', 'Fredek', 'Raddie', 'Goudie', 'rgoudie5@blogs.com', 'FRG1', 2022, 280),
#  ('10509348-a882-11ec-a3ad-edb7cbd2bb34', 'Carroll', None, 'Venables', 'rvenablesu@friendfeed.com', 'CV1', 2019, 281),
#  ('1050c6ce-a882-11ec-a3ad-edb7cbd2bb34', 'Meridel', 'Rawley', 'Willatts', 'rwillatts1t@si.edu', 'MRW1', 2022, 282),
#  ('1050fe00-a882-11ec-a3ad-edb7cbd2bb34', 'Kearney', 'Selie', 'Gino', 'sgino1l@bluehost.com', 'KSG1', 2016, 283),
#  ('10523298-a882-11ec-a3ad-edb7cbd2bb34', 'Drona', None, 'McKinie', 'smckinie1a@springer.com', 'DM2', 2018, 284),
#  ('1052850e-a882-11ec-a3ad-edb7cbd2bb34', 'Sterne', 'Sasha', 'Spooner', 'sspooner1f@wordpress.org', 'SSS1', 2020, 285),
#  ('1052b75e-a882-11ec-a3ad-edb7cbd2bb34', 'Nonna', None, 'Gillanders', 'tgillanders9@example.com', 'NG2', 2021, 286),
#  ('1052eb52-a882-11ec-a3ad-edb7cbd2bb34', 'Norry', None, 'Rubinchik', 'trubinchik16@howstuffworks.com', 'NR1', 2016, 287),
#  ('1053494e-a882-11ec-a3ad-edb7cbd2bb34', 'Gerty', None, "O'Donegan", 'vodoneganf@clickbank.net', 'GO1', 2020, 288),
#  ('1053740a-a882-11ec-a3ad-edb7cbd2bb34', 'Anabelle', 'Wallas', 'Quimby', 'wquimby1c@nba.com', 'AWQ1', 2022, 289)]

# %%
#
# Test that we loaded employees.
#
# %sql select * from employee;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 50 rows affected.
# [('103e6a74-a882-11ec-a3ad-edb7cbd2bb34', 'Sanders', 'Arline', 'Breckell', 'abreckell1x@fotki.com', 'SAB1', 'Professor', 192),
#  ('103f2a54-a882-11ec-a3ad-edb7cbd2bb34', 'Ethelin', None, 'Fidele', 'afidele12@google.ru', 'EF1', 'Lecturer', 193),
#  ('103fa696-a882-11ec-a3ad-edb7cbd2bb34', 'Xenia', 'Ardella', 'Kief', 'akieft@free.fr', 'XAK1', 'Staff', 194),
#  ('103fe1ec-a882-11ec-a3ad-edb7cbd2bb34', 'Cari', 'Andriana', 'Leask', 'aleask1n@devhub.com', 'CAL1', 'Lecturer', 195),
#  ('10409f88-a882-11ec-a3ad-edb7cbd2bb34', 'Lemmy', 'Burr', 'Bradnocke', 'bbradnockek@nifty.com', 'LBB1', 'Lecturer', 196),
#  ('10411828-a882-11ec-a3ad-edb7cbd2bb34', 'Sibylle', 'Bearnard', 'Lalley', 'blalley2d@rediff.com', 'SBL1', 'Lecturer', 197),
#  ('1041cc50-a882-11ec-a3ad-edb7cbd2bb34', 'Lu', 'Cinnamon', 'Flaxman', 'cflaxman1b@cdbaby.com', 'LCF1', 'Lecturer', 198),
#  ('1043122c-a882-11ec-a3ad-edb7cbd2bb34', 'Hobart', 'Dominic', 'Croal', 'dcroalx@purevolume.com', 'HDC1', 'Professor', 199),
#  ('10434364-a882-11ec-a3ad-edb7cbd2bb34', 'Marylin', 'Darcy', 'Favey', 'dfavey2p@mozilla.com', 'MDF1', 'Staff', 200),
#  ('1043a598-a882-11ec-a3ad-edb7cbd2bb34', 'Ailbert', 'Danie', 'Warmisham', 'dwarmishame@soundcloud.com', 'ADW1', 'Staff', 201),
#  ('10440c22-a882-11ec-a3ad-edb7cbd2bb34', 'Karon', None, 'Bree', 'ebree1z@creativecommons.org', 'KB1', 'Professor', 202),
#  ('10448a62-a882-11ec-a3ad-edb7cbd2bb34', 'Maybelle', 'Esteban', 'Cella', 'ecella26@mail.ru', 'MEC1', 'Staff', 203),
#  ('1044d36e-a882-11ec-a3ad-edb7cbd2bb34', 'Lelah', 'Ellette', 'Fulk', 'efulk1d@discuz.net', 'LEF1', 'Staff', 204),
#  ('10471598-a882-11ec-a3ad-edb7cbd2bb34', 'Gisela', None, 'Blagden', 'gblagden1q@buzzfeed.com', 'GB1', 'Professor', 205),
#  ('10479086-a882-11ec-a3ad-edb7cbd2bb34', 'Niki', 'Gardiner', 'Form', 'gform18@blogger.com', 'NGF1', 'Staff', 206),
#  ('1047c452-a882-11ec-a3ad-edb7cbd2bb34', 'Suki', None, 'Hellyar', 'ghellyar2a@cornell.edu', 'SH1', 'Staff', 207),
#  ('10486628-a882-11ec-a3ad-edb7cbd2bb34', 'Carmine', None, 'Tolman', 'gtolmanr@slideshare.net', 'CT1', 'Staff', 208),
#  ('10489936-a882-11ec-a3ad-edb7cbd2bb34', 'Wells', None, 'Yousef', 'gyousef2r@spotify.com', 'WY1', 'Professor', 209),
#  ('1049298c-a882-11ec-a3ad-edb7cbd2bb34', 'Christie', None, 'Siegertsz', 'hsiegertsz21@instagram.com', 'CS1', 'Professor', 210),
#  ('10495588-a882-11ec-a3ad-edb7cbd2bb34', 'Doyle', None, 'Aslin', 'jaslin24@redcross.org', 'DA2', 'Lecturer', 211),
#  ('104989f4-a882-11ec-a3ad-edb7cbd2bb34', 'Robinett', 'Jami', 'Charte', 'jcharte1y@merriam-webster.com', 'RJC1', 'Staff', 212),
#  ('1049b9f6-a882-11ec-a3ad-edb7cbd2bb34', 'Olwen', None, 'Hedley', 'jhedley1m@disqus.com', 'OH1', 'Staff', 213),
#  ('104a4b96-a882-11ec-a3ad-edb7cbd2bb34', 'Renae', 'Jaquith', 'Plessing', 'jplessing0@samsung.com', 'RJP1', 'Staff', 214),
#  ('104ad9e4-a882-11ec-a3ad-edb7cbd2bb34', 'Lilllie', None, 'Snodin', 'jsnodin20@princeton.edu', 'LS1', 'Lecturer', 215),
#  ('104b39de-a882-11ec-a3ad-edb7cbd2bb34', 'Sayers', 'Karon', 'McKnish', 'kmcknishs@reddit.com', 'SKM1', 'Lecturer', 216),
#  ('104b6ee0-a882-11ec-a3ad-edb7cbd2bb34', 'Electra', 'Krystle', 'Morfell', 'kmorfell2g@istockphoto.com', 'EKM1', 'Professor', 217),
#  ('104b9cda-a882-11ec-a3ad-edb7cbd2bb34', 'Matthieu', 'Kalle', 'Slipper', 'kslipper2f@nytimes.com', 'MKS1', 'Staff', 218),
#  ('104bd38a-a882-11ec-a3ad-edb7cbd2bb34', 'Nadia', None, 'Trehearn', 'ktrehearn19@tinyurl.com', 'NT1', 'Lecturer', 219),
#  ('104c009e-a882-11ec-a3ad-edb7cbd2bb34', 'Clim', None, 'Guislin', 'lguislin2o@chicagotribune.com', 'CG1', 'Professor', 220),
#  ('104c5eae-a882-11ec-a3ad-edb7cbd2bb34', 'Holli', None, 'Henstridge', 'lhenstridgeh@sogou.com', 'HH1', 'Lecturer', 221),
#  ('104c902c-a882-11ec-a3ad-edb7cbd2bb34', 'Meghan', None, 'Kleinschmidt', 'lkleinschmidtl@squarespace.com', 'MK2', 'Lecturer', 222),
#  ('104cbcaa-a882-11ec-a3ad-edb7cbd2bb34', 'Genni', None, 'Purbrick', 'lpurbrick25@canalblog.com', 'GP1', 'Professor', 223),
#  ('104ce9c8-a882-11ec-a3ad-edb7cbd2bb34', 'Bonny', None, 'Scheffel', 'lscheffel7@taobao.com', 'BS1', 'Professor', 224),
#  ('104d14ca-a882-11ec-a3ad-edb7cbd2bb34', 'Mendie', None, 'Tennick', 'ltennick3@aboutads.info', 'MT1', 'Staff', 225),
#  ('104d6c04-a882-11ec-a3ad-edb7cbd2bb34', 'Karole', None, 'Inkin', 'minkinc@google.de', 'KI1', 'Staff', 226),
#  ('104dcb9a-a882-11ec-a3ad-edb7cbd2bb34', 'Kahaleel', 'Meg', 'Penzer', 'mpenzer14@dailymail.co.uk', 'KMP1', 'Professor', 227),
#  ('104e268a-a882-11ec-a3ad-edb7cbd2bb34', 'Darrin', 'Mario', 'Wynrahame', 'mwynrahamem@admin.ch', 'DMW1', 'Professor', 228),
#  ('104e64b0-a882-11ec-a3ad-edb7cbd2bb34', 'Carey', 'Maudie', 'Wyrall', 'mwyrallj@scientificamerican.com', 'CMW1', 'Staff', 229),
#  ('104e98ea-a882-11ec-a3ad-edb7cbd2bb34', 'Jacky', 'Nydia', 'Bolles', 'nbolles23@ucoz.ru', 'JNB1', 'Staff', 230),
#  ('104ed44a-a882-11ec-a3ad-edb7cbd2bb34', 'Francene', None, 'MacNeely', 'nmacneely22@cpanel.net', 'FM1', 'Lecturer', 231),
#  ('105016e8-a882-11ec-a3ad-edb7cbd2bb34', 'Bamby', 'Rubetta', 'Mabbs', 'rmabbs4@xing.com', 'BRM1', 'Lecturer', 232),
#  ('1050566c-a882-11ec-a3ad-edb7cbd2bb34', 'Ari', 'Rheta', 'Sellek', 'rsellek6@oakley.com', 'ARS1', 'Lecturer', 233),
#  ('10513686-a882-11ec-a3ad-edb7cbd2bb34', 'Bettina', 'Sonya', 'Higgonet', 'shiggonet2b@163.com', 'BSH1', 'Lecturer', 234),
#  ('10516af2-a882-11ec-a3ad-edb7cbd2bb34', 'Jany', 'Sherry', 'Johl', 'sjohlg@soundcloud.com', 'JSJ1', 'Professor', 235),
#  ('105199d2-a882-11ec-a3ad-edb7cbd2bb34', 'Pattie', None, 'Lyles', 'slyles1j@amazon.de', 'PL1', 'Staff', 236),
#  ('1051c8d0-a882-11ec-a3ad-edb7cbd2bb34', 'Kristin', None, 'Malacrida', 'smalacrida1w@economist.com', 'KM2', 'Staff', 237),
#  ('1052055c-a882-11ec-a3ad-edb7cbd2bb34', 'Yehudi', 'Sile', 'McColley', 'smccolleyq@amazon.com', 'YSM1', 'Staff', 238),
#  ('10525aca-a882-11ec-a3ad-edb7cbd2bb34', 'Duncan', 'Shellie', 'Sillars', 'ssillars2l@unicef.org', 'DSS1', 'Professor', 239),
#  ('10531bd6-a882-11ec-a3ad-edb7cbd2bb34', 'Doug', None, 'Medforth', 'vmedforth1o@homestead.com', 'DM3', 'Staff', 240),
#  ('1053a128-a882-11ec-a3ad-edb7cbd2bb34', 'Sasha', 'Win', 'Ruffli', 'wruffli2q@wordpress.com', 'SWR1', 'Lecturer', 241)]

# %% [markdown]
# Your tests should be below. You should have test cells that test:
#
# 1. Successful execution of each procedure.
# <br><br>
# 2. Execution of update procedures showing that your constraints prevent incorrect data entry and enforce the defined semantics and behavior.
# <br><br>
# 3. Demonstrating that:
#     1. You create a user ```general_user.```
#     2. ```general_user``` can query the data and call the procedures, but cannot perform ```INSERT, UPDATE, DELETE.```
